# %%
# %matplotlib inline

# %%
import numpy as np
import scipy as sp
import scipy.stats
import matplotlib.pyplot as plt

# %%
np.seterr(all='raise')
# Out:
# {'divide': 'warn', 'invalid': 'warn', 'under': 'ignore', 'over': 'warn'}

# %%
# ロジスティックシグモイド関数
sigmoid = np.vectorize(lambda x: 1.0 / (1.0 + np.exp(-x)))

# %%
# ロジスティック回帰で重みベクトルを求める
# - 引数m0, S0invを与えれば正則化項あり、与えなければ正則化項なしで計算する。
# - 引数w_initで繰り返しの初期値を指定できる。
def logistic_regression(x, t, m0=None, S0inv=None, w_init=None, iter=100):
    Phi = np.column_stack((np.ones(x.shape[0]), x))
    n, dim = Phi.shape
    if m0 is None: m0 = np.zeros(dim)
    if S0inv is None: S0inv = np.zeros((dim, dim))
    if w_init is None: w = np.zeros(dim)
    else: w = w_init.copy()

    history = [(0, w.copy())]
    try:
        for i in range(iter):
            y = sigmoid(w.dot(Phi.T))
            R = (y * (1 - y)).reshape((n, 1))
            grad = Phi.T.dot(y - t) + S0inv.dot(w - m0)
            H = Phi.T.dot(R * Phi) + S0inv
            w -= sp.linalg.inv(H).dot(grad)
            # ↓これを入れないと、条件によってoverflowやunderflowが起こる。
            # 　wの絶対値が大きくならなければ、分母はなんでもよい？
            # w /= np.linalg.norm(w)
            history.append((i + 1, w.copy()))
    except Exception as e:
        return w, history, e
    return w, history, None

# %%
# グラフの体裁を整える
def arrange_plot():
    ax = plt.gca()
    ax.set_aspect(1)
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    plt.xlim(-4.0, 8.0)
    plt.ylim(-4.0, 6.0)

# データ集合をプロットする
def plot_data(x, t):
    arrange_plot()
    for i in range(x.shape[0]):
        plt.scatter(x[i, 0], x[i, 1],
                    color = ['red', 'blue'][int(t[i])],
                    marker = ['x', 'o'][int(t[i])])

# 決定境界をプロットする
def plot_w(w, **kwargs):
    xx = np.linspace(-4.0, 8.0, 100)
    plt.plot(xx, np.vectorize(lambda x1: - (x1 * w[1] + w[0]) / w[2])(xx), **kwargs)

# %%
# データ集合 その1
N = 50
np.random.seed(0)
t_1 = np.r_[np.ones(N),
            np.zeros(N)]
x_1 = np.r_[sp.stats.multivariate_normal.rvs([2.0, 0.0], [[3.0, 0.8], [0.8, 0.5]], N),
            sp.stats.multivariate_normal.rvs([-1.0, 3.0], [[3.0, 0.8], [0.8, 0.5]], N)]

# %%
# データ集合 その2
# その1と乱数の種だけが異なる。
N = 50
np.random.seed(1)
t_2 = np.r_[np.ones(N),
            np.zeros(N)]
x_2 = np.r_[sp.stats.multivariate_normal.rvs([2.0, 0.0], [[3.0, 0.8], [0.8, 0.5]], N),
            sp.stats.multivariate_normal.rvs([-1.0, 3.0], [[3.0, 0.8], [0.8, 0.5]], N)]

# %%
plot_data(x_1, t_1)

# %%
plot_data(x_2, t_2)

# %%
# テスト用パラメータ
ws = [np.array([0.0, 0.0, -1.0]),
      np.array([0.0, 0.5, -1.0]),
      np.array([1.0, 0.5, -1.0]),
      np.array([1.0, 1.0, -1.0])]
m0s = [np.array([0.0, 0.0, -1.0]),
       np.array([0.0, 0.5, -1.0]),
       np.array([1.0, 0.5, -1.0]),
       np.array([1.0, 1.0, -1.0])]
I = np.identity(ws[0].shape[0])

colors = ['r', 'g', 'b', 'y']

# %%
# テスト用関数
def test(x, t, c, m0=None, S0inv=None, w_init=None, iter=100):
    w, history, e = logistic_regression(x, t, m0=m0, S0inv=S0inv, w_init=w_init, iter=iter)

    plot_w(w, color=c)
    if m0 is not None: plot_w(m0, color=c, linestyle='--')

    print("w_init = ", w_init, "m0 = ", m0)
    for (i, w_hist) in history[-5:]:
        print(i, w_hist, - w_hist / w_hist[2])
    if e: print(e)
    print()

# %% [markdown]
# # テスト1
#
# - 正則化項なし。
# - wの初期値をいろいろ変えてみる。

# %%
# データ集合その1の場合
plot_data(x_1, t_1)
for w_init, c in zip(ws, colors):
    test(x_1, t_1, c, w_init=w_init, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  None
# 96 [ 82.16444495  19.15155131 -73.74175218] [ 1.11421878  0.2597111  -1.        ]
# 97 [ 82.16444495  19.15155131 -73.74175218] [ 1.11421878  0.2597111  -1.        ]
# 98 [ 82.16444495  19.15155131 -73.74175218] [ 1.11421878  0.2597111  -1.        ]
# 99 [ 82.16444495  19.15155131 -73.74175218] [ 1.11421878  0.2597111  -1.        ]
# 100 [ 82.16444495  19.15155131 -73.74175218] [ 1.11421878  0.2597111  -1.        ]
#
# w_init =  [ 0.   0.5 -1. ] m0 =  None
# 75 [ 80.44484923  18.75501465 -71.99877626] [ 1.11730856  0.26049074 -1.        ]
# 76 [ 82.44484923  19.13001465 -73.49877626] [ 1.12171731  0.26027664 -1.        ]
# 77 [ 81.44436095  19.12998413 -73.49877626] [ 1.10810499  0.26027623 -1.        ]
# 78 [ 81.44436095  20.12998413 -73.49877626] [ 1.10810499  0.2738819  -1.        ]
# 79 [ 82.44436095  12.12998413 -73.49877626] [ 1.12171066  0.16503655 -1.        ]
# singular matrix
#
# w_init =
#  [ 1.   0.5 -1. ] m0 =  None
# 73 [ 80.41806532  18.56881758 -71.31773606] [ 1.12760261  0.26036746 -1.        ]
# 74 [ 82.16806532  18.88131758 -72.44273606] [ 1.13424851  0.26063783 -1.        ]
# 75 [ 81.16806532  18.88131758 -72.4429802 ] [ 1.12044073  0.26063695 -1.        ]
# 76 [ 81.16806532   2.88131758 -68.4429802 ] [ 1.18592243  0.04209807 -1.        ]
# 77 [ -2.68916198e+09  -2.04723475e+09   9.67929655e+09] [ 0.27782618  0.21150656 -1.        ]
# overflow encountered in exp
#
# w_init =
#  [ 1.  1. -1.] m0 =  None
# 96 [ 81.5613313   18.90145211 -73.1556163 ] [ 1.11490184  0.25837322 -1.        ]
# 97 [ 81.5613313   18.90145211 -73.1556163 ] [ 1.11490184  0.25837322 -1.        ]
# 98 [ 81.5613313   18.90145211 -73.1556163 ] [ 1.11490184  0.25837322 -1.        ]
# 99 [ 81.5613313   18.90145211 -73.1556163 ] [ 1.11490184  0.25837322 -1.        ]
# 100 [ 81.5613313   18.90145211 -73.1556163 ] [ 1.11490184  0.25837322 -1.        ]

# %%
# データ集合その2の場合
plot_data(x_2, t_2)
for w_init, c in zip(ws, colors):
    test(x_2, t_2, c, w_init=w_init, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  None
# 90 [ 86.60975795  17.63379346 -78.63792629] [ 1.10137388  0.22424032 -1.        ]
# 91 [ 88.51600795  17.97314893 -80.10667629] [ 1.10497666  0.22436518 -1.        ]
# 92 [ 87.51405483  17.97314893 -80.10716457] [ 1.09246227  0.22436381 -1.        ]
# 93 [ 90.26405483  18.28564893 -82.60716457] [ 1.09269039  0.22135669 -1.        ]
# 94 [ 89.26600795  18.28589307 -82.60911769] [ 1.080583    0.22135442 -1.        ]
# singular matrix
#
# w_init =  [ 0.   0.5 -1. ] m0 =  None
# 96 [ 51.30067523  26.93037129 -53.86956652] [ 0.95231275  0.4999181  -1.        ]
# 97 [ 51.30067523  26.93037129 -53.86956652] [ 0.95231275  0.4999181  -1.        ]
# 98 [ 51.30067523  26.93037129 -53.86956652] [ 0.95231275  0.4999181  -1.        ]
# 99 [ 51.30067523  26.93037129 -53.86956652] [ 0.95231275  0.4999181  -1.        ]
# 100 [ 51.30067523  26.93037129 -53.86956652] [ 0.95231275  0.4999181  -1.        ]
#
# w_init =  [ 1.   0.5 -1. ] m0 =  None
# 55 [ 67.6527052   18.73155531 -60.20565537] [ 1.12369353  0.31112618 -1.        ]
# 56 [ 69.1527052   19.10655531 -61.45565537] [ 1.12524559  0.31089987 -1.        ]
# 57 [ 68.1527052   19.10655531 -61.45565537] [ 1.10897369  0.31089987 -1.        ]
# 58 [  4.1527052   19.10655531 -29.45565537] [ 0.14098159  0.6486549  -1.        ]
# 59 [ -53.7747443  -292.01474806  483.9426259 ] [ 0.11111802  0.60340779 -1.        ]
# overflow encountered in exp
#
# w_init =
#  [ 1.  1. -1.] m0 =  None
# 96 [ 50.20976547  23.45723914 -47.88397148] [ 1.04857145  0.48987664 -1.        ]
# 97 [ 50.20976547  23.45723914 -47.88397148] [ 1.04857145  0.48987664 -1.        ]
# 98 [ 50.20976547  23.45723914 -47.88397148] [ 1.04857145  0.48987664 -1.        ]
# 99 [ 50.20976547  23.45723914 -47.88397148] [ 1.04857145  0.48987664 -1.        ]
# 100 [ 50.20976547  23.45723914 -47.88397148] [ 1.04857145  0.48987664 -1.        ]

# %% [markdown]
# # テスト2
# - 正則化項あり。
# - 正則化パラメータは同じで、wの初期値をいろいろ変えてみる。

# %%
# データ集合その1の場合
plot_data(x_1, t_1)
for w_init, c in zip(ws, colors):
    test(x_1, t_1, c, w_init=w_init, m0=m0s[0], S0inv=I, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 97 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 98 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 99 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 100 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
#
# w_init =  [ 0.   0.5 -1. ]
#  m0 =  [ 0.  0. -1.]
# 96 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 97 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 98 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 99 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 100 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
#
# w_init =
#  [ 1.   0.5 -1. ] m0 =  [ 0.  0. -1.]
# 96 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 97 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 98 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 99 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 100 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
#
# w_init =
#  [ 1.  1. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 97 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 98 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 99 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 100 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]

# %%
# データ集合その2の場合
plot_data(x_2, t_2)
for w_init, c in zip(ws, colors):
    test(x_2, t_2, c, w_init=w_init, m0=m0s[0], S0inv=I, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 97 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 98 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 99 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 100 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
#
# w_init =  [ 0.   0.5 -1. ] m0 =  [ 0.  0. -1.]
# 96 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 97 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 98 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 99 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 100 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
#
# w_init =
#  [ 1.   0.5 -1. ] m0 =  [ 0.  0. -1.]
# 96 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 97 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 98 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 99 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 100 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
#
# w_init =
#  [ 1.  1. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 97 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 98 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 99 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 100 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]

# %% [markdown]
# # テスト3
# - 正則化項あり。
# - wの初期値は同じで、正則化パラメータをいろいろ変えてみる。

# %%
# データ集合その1の場合
plot_data(x_1, t_1)
for m0, c in zip(m0s, colors):
    test(x_1, t_1, c, w_init=ws[0], m0=m0, S0inv=I, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 97 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 98 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 99 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
# 100 [ 1.854077    1.07931504 -2.02794679] [ 0.91426314  0.53222059 -1.        ]
#
# w_init =
# [ 0.  0. -1.] m0 =  [ 0.   0.5 -1. ]
# 96 [ 1.83422307  1.16406179 -2.04390212] [ 0.89741238  0.56952913 -1.        ]
# 97 [ 1.83422307  1.16406179 -2.04390212] [ 0.89741238  0.56952913 -1.        ]
# 98 [ 1.83422307  1.16406179 -2.04390212] [ 0.89741238  0.56952913 -1.        ]
# 99 [ 1.83422307  1.16406179 -2.04390212] [ 0.89741238  0.56952913 -1.        ]
# 100 [ 1.83422307  1.16406179 -2.04390212] [ 0.89741238  0.56952913 -1.        ]
#
# w_init =
#  [ 0.  0. -1.] m0 =  [ 1.   0.5 -1. ]
# 96 [ 2.21151571  1.12820373 -2.143101  ] [ 1.03192323  0.52643517 -1.        ]
# 97 [ 2.21151571  1.12820373 -2.143101  ] [ 1.03192323  0.52643517 -1.        ]
# 98 [ 2.21151571  1.12820373 -2.143101  ] [ 1.03192323  0.52643517 -1.        ]
# 99 [ 2.21151571  1.12820373 -2.143101  ] [ 1.03192323  0.52643517 -1.        ]
# 100 [ 2.21151571  1.12820373 -2.143101  ] [ 1.03192323  0.52643517 -1.        ]
#
# w_init =
#  [ 0.  0. -1.] m0 =  [ 1.  1. -1.]
# 96 [ 2.19661207  1.23842014 -2.16065088] [ 1.01664368  0.57316994 -1.        ]
# 97 [ 2.19661207  1.23842014 -2.16065088] [ 1.01664368  0.57316994 -1.        ]
# 98 [ 2.19661207  1.23842014 -2.16065088] [ 1.01664368  0.57316994 -1.        ]
# 99 [ 2.19661207  1.23842014 -2.16065088] [ 1.01664368  0.57316994 -1.        ]
# 100 [ 2.19661207  1.23842014 -2.16065088] [ 1.01664368  0.57316994 -1.        ]

# %%
# データ集合その2の場合
plot_data(x_2, t_2)
for m0, c in zip(m0s, colors):
    test(x_2, t_2, c, w_init=ws[0], m0=m0, S0inv=I, iter=100)
# Out:
# w_init =  [ 0.  0. -1.] m0 =  [ 0.  0. -1.]
# 96 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 97 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 98 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 99 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
# 100 [ 1.54001256  1.32751277 -1.93643285] [ 0.79528322  0.68554547 -1.        ]
#
# w_init =
#  [ 0.  0. -1.] m0 =  [ 0.   0.5 -1. ]
# 96 [ 1.50588044  1.44544306 -1.95466423] [ 0.77040364  0.73948407 -1.        ]
# 97 [ 1.50588044  1.44544306 -1.95466423] [ 0.77040364  0.73948407 -1.        ]
# 98 [ 1.50588044  1.44544306 -1.95466423] [ 0.77040364  0.73948407 -1.        ]
# 99 [ 1.50588044  1.44544306 -1.95466423] [ 0.77040364  0.73948407 -1.        ]
# 100 [ 1.50588044  1.44544306 -1.95466423] [ 0.77040364  0.73948407 -1.        ]
#
# w_init =
#  [ 0.  0. -1.] m0 =  [ 1.   0.5 -1. ]
# 96 [ 1.91587114  1.38303143 -2.02190421] [ 0.94755782  0.68402421 -1.        ]
# 97 [ 1.91587114  1.38303143 -2.02190421] [ 0.94755782  0.68402421 -1.        ]
# 98 [ 1.91587114  1.38303143 -2.02190421] [ 0.94755782  0.68402421 -1.        ]
# 99 [ 1.91587114  1.38303143 -2.02190421] [ 0.94755782  0.68402421 -1.        ]
# 100 [ 1.91587114  1.38303143 -2.02190421] [ 0.94755782  0.68402421 -1.        ]
#
# w_init =
#  [ 0.  0. -1.] m0 =  [ 1.  1. -1.]
# 96 [ 1.88908132  1.53225493 -2.03694298] [ 0.92741002  0.75223261 -1.        ]
# 97 [ 1.88908132  1.53225493 -2.03694298] [ 0.92741002  0.75223261 -1.        ]
# 98 [ 1.88908132  1.53225493 -2.03694298] [ 0.92741002  0.75223261 -1.        ]
# 99 [ 1.88908132  1.53225493 -2.03694298] [ 0.92741002  0.75223261 -1.        ]
# 100 [ 1.88908132  1.53225493 -2.03694298] [ 0.92741002  0.75223261 -1.        ]
